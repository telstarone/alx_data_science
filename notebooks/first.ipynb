# %% [markdown]
# #Test
# Testing ds_alx ENV

# %%
# %pip install jupysql --upgrade
# Out:
# ...
#    ---------------------------------------- 0.0/611.4 kB ? eta -:--:--
#    ---------------------------------------- 611.4/611.4 kB 4.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
#    ---------------------------------------- 0/7 [sqlglot]
# ...
